# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/corazzon/boostcourse-ds-510/blob/master/open-data-analysis-input.ipynb)
#
#
# # 공공데이터 상권정보 분석해 보기
# * https://www.data.go.kr/dataset/15012005/fileData.do
# * 국가중점데이터인 상권정보를 살펴봅니다.
# * 처음으로 파일데이터에서 `상가(상권)정보_의료기관_201909`를 다운로드 받아봅니다.

# %% [markdown]
# ## 필요한 라이브러리 불러오기

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %% [markdown]
# ## 시각화를 위한 폰트 설정

# %%
# 한글폰트 사용을 위해 설치
# 아래 모듈을 설치하고 불러오면 별도의 한글폰트 설정이 필요 없습니다.
# !pip install koreanize-matplotlib

# import koreanize_matplotlib

# %%
import matplotlib.pyplot as plt
from IPython.display import set_matplotlib_formats
# Window 의 한글 폰트 설정
plt.rc('font',family='Malgun Gothic')
# Mac 의 한글 폰트 설정
# plt.rc('font', family='AppleGothic')
# plt.rc('axes', unicode_minus=False)

# 폰트가 선명하게 보이기 위해 - 그래프에 retina display 적용
# retina 대신 svg 등의 설정을 할 수도 있으며
# 디스플레이(모니터)가 retina 를 지원해야만 선명한 차이를 볼 수 있습니다.
# %config InlineBackend.figure_format = 'retina'

# 그래프가 노트북 안에 보이게 하기 위해
# %matplotlib inline

# %% [markdown]
# ## 데이터 로드하기
# * 판다스에서 데이터를 로드할 때는 read_csv를 사용합니다.
# * 데이터를 로드해서 df라는 변수에 담습니다.
# * 그리고 shape 를 통해 데이터의 갯수를 찍습니다. 결과는 (행, 열) 순으로 출력됩니다.

# %%
df = pd.read_csv("소상공인시장진흥공단_상가업소정보_의료기관_201909.csv", low_memory=False)
df.shape
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_1015/583548468.py in <cell line: 0>()
# ----> 1 df = pd.read_csv("소상공인시장진흥공단_상가업소정보_의료기관_201909.csv", low_memory=False)
#       2 df.shape
#
# /usr/local/lib/python3.13/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1024     kwds.update(kwds_defaults)
#    1025
# -> 1026     return _read(filepath_or_buffer, kwds)
#    1027
#    1028
#
# /usr/local/lib/python3.13/dist-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     618
#     619     # Create the parser.
# --> 620     parser = TextFileReader(filepath_or_buffer, **kwds)
#     621
#     622     if chunksize or iterator:
#
# /usr/local/lib/python3.13/dist-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#    1618
#    1619         self.handles: IOHandles | None = None
# -> 1620         self._engine = self._make_engine(f, self.engine)
#    1621
#    1622     def close(self) -> None:
#
# /usr/local/lib/python3.13/dist-packages/pandas/io/parsers/readers.py in _make_engine(self, f, engine)
#    1878                 if "b" not in mode:
#    1879                     mode += "b"
# -> 1880             self.handles = get_handle(
#    1881                 f,
#    1882                 mode,
#
# /usr/local/lib/python3.13/dist-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     871         if ioargs.encoding and "b" not in ioargs.mode:
#     872             # Encoding
# --> 873             handle = open(
#     874                 handle,
#     875                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: '소상공인시장진흥공단_상가업소정보_의료기관_201909.csv'

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# ## 데이터 미리보기
# * head, tail 을 통해 데이터를 미리 볼 수 있습니다.

# %%
# head 로 데이터를 미리보기 합니다.
# shift + tap 키를 누르면 공식문서 보기 가능
df.head()
# Out:
#      상가업소번호     상호명  지점명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드 상권업종중분류명 상권업종소분류코드  \
# 0  19956873  하나산부인과  NaN         S       의료       S01       병원    S01B10
#
#   상권업종소분류명 표준산업분류코드  ...                     건물관리번호      건물명  \
# 0     산부인과   Q86201  ...  4127310900110810000010857  산호한양아파트
#
#                 도로명주소     구우편번호    신우편번호  동정보  층정보  호정보          경도         위도
# 0  경기도 안산시 단원구 달미로 10  425764.0  15236.0  NaN  NaN  NaN  126.814295  37.336344
#
# [1 rows x 39 columns]

# %%
# tail 로 마지막 부분에 있는 데이터를 불러옵니다.
df.tail(1)
# Out:
#          상가업소번호     상호명  지점명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드 상권업종중분류명 상권업종소분류코드  \
# 28240  24024239  맘앤키즈약국  NaN         S       의료       NaN      NaN       NaN
#
#       상권업종소분류명 표준산업분류코드  ... 건물관리번호  건물명 도로명주소  구우편번호 신우편번호  동정보  층정보  호정보  \
# 28240      NaN      NaN  ...    NaN  NaN   NaN    NaN   NaN  NaN  NaN  NaN
#
#        경도  위도
# 28240 NaN NaN
#
# [1 rows x 39 columns]

# %%
# sample 로 미리보기를 합니다.
df.sample()
# Out:
#       상가업소번호    상호명  지점명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드 상권업종중분류명 상권업종소분류코드  \
# 79  21403242  은성복지회  NaN         S       의료       S01       병원    S01B17
#
#    상권업종소분류명 표준산업분류코드  ...                     건물관리번호    건물명             도로명주소  \
# 79  노인/치매병원   Q86102  ...  4615010800200220000080503  향림실버빌  전라남도 순천시 조비길 298
#
#        구우편번호    신우편번호  동정보  층정보  호정보          경도         위도
# 79  540950.0  57922.0  NaN  NaN  NaN  127.460606  34.991014
#
# [1 rows x 39 columns]

# %% [markdown]
# ## 데이터 요약하기

# %% [markdown]
# ### 요약정보

# %%
# info로 데이터의 요약을 봅니다.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28241 entries, 0 to 28240
# Data columns (total 39 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   상가업소번호     28241 non-null  int64
#  1   상호명        28241 non-null  object
#  2   지점명        491 non-null    object
#  3   상권업종대분류코드  28241 non-null  object
#  4   상권업종대분류명   28241 non-null  object
#  5   상권업종중분류코드  28240 non-null  object
#  6   상권업종중분류명   28240 non-null  object
#  7   상권업종소분류코드  28240 non-null  object
#  8   상권업종소분류명   28240 non-null  object
#  9   표준산업분류코드   26996 non-null  object
#  10  표준산업분류명    26996 non-null  object
#  11  시도코드       28079 non-null  float64
#  12  시도명        28079 non-null  object
#  13  시군구코드      28079 non-null  float64
#  14  시군구명       28079 non-null  object
#  15  행정동코드      28240 non-null  float64
#  16  행정동명       28079 non-null  object
#  17  법정동코드      28224 non-null  float64
#  18  법정동명       28224 non-null  object
#  19  지번코드       28240 non-null  float64
#  20  대지구분코드     28240 non-null  float64
#  21  대지구분명      28240 non-null  object
#  22  지번본번지      28240 non-null  float64
#  23  지번부번지      22239 non-null  float64
#  24  지번주소       28240 non-null  object
#  25  도로명코드      28240 non-null  float64
#  26  도로명        28240 non-null  object
#  27  건물본번지      28240 non-null  float64
#  28  건물부번지      3999 non-null   float64
#  29  건물관리번호     28240 non-null  object
#  30  건물명        13721 non-null  object
#  31  도로명주소      28240 non-null  object
#  32  구우편번호      28240 non-null  float64
#  33  신우편번호      28240 non-null  float64
#  34  동정보        2726 non-null   object
#  35  층정보        14649 non-null  object
#  36  호정보        4597 non-null   object
#  37  경도         28240 non-null  float64
#  38  위도         28240 non-null  float64
# dtypes: float64(15), int64(1), object(23)
# memory usage: 8.4+ MB

# %% [markdown]
# ### 컬럼명 보기

# %%
# 컬럼명만 출력해 봅니다.
df.columns
# Out:
# Index(['상가업소번호', '상호명', '지점명', '상권업종대분류코드', '상권업종대분류명', '상권업종중분류코드',
#        '상권업종중분류명', '상권업종소분류코드', '상권업종소분류명', '표준산업분류코드', '표준산업분류명', '시도코드',
#        '시도명', '시군구코드', '시군구명', '행정동코드', '행정동명', '법정동코드', '법정동명', '지번코드',
#        '대지구분코드', '대지구분명', '지번본번지', '지번부번지', '지번주소', '도로명코드', '도로명', '건물본번지',
#        '건물부번지', '건물관리번호', '건물명', '도로명주소', '구우편번호', '신우편번호', '동정보', '층정보',
#        '호정보', '경도', '위도'],
#       dtype='object')

# %% [markdown]
# ### 데이터 타입

# %%
# 데이터 타입만 출력합니다.
df.dtypes
# Out:
# 상가업소번호         int64
# 상호명           object
# 지점명           object
# 상권업종대분류코드     object
# 상권업종대분류명      object
# 상권업종중분류코드     object
# 상권업종중분류명      object
# 상권업종소분류코드     object
# 상권업종소분류명      object
# 표준산업분류코드      object
# 표준산업분류명       object
# 시도코드         float64
# 시도명           object
# 시군구코드        float64
# 시군구명          object
# 행정동코드        float64
# 행정동명          object
# 법정동코드        float64
# 법정동명          object
# 지번코드         float64
# 대지구분코드       float64
# 대지구분명         object
# 지번본번지        float64
# 지번부번지        float64
# 지번주소          object
# 도로명코드        float64
# 도로명           object
# 건물본번지        float64
# 건물부번지        float64
# 건물관리번호        object
# 건물명           object
# 도로명주소         object
# 구우편번호        float64
# 신우편번호        float64
# 동정보           object
# 층정보           object
# 호정보           object
# 경도           float64
# 위도           float64
# dtype: object

# %% [markdown]
# ## 결측치

# %%
null_count= df.isnull().sum()
null_count
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1015/3083929962.py in <cell line: 0>()
# ----> 1 null_count= df.isnull().sum()
#       2 null_count
#
# NameError: name 'df' is not defined

# %%
# 위에서 구한 결측치를 .plot.bar 를 통해 막대그래프로 표현합니다.

# %%
# 위에서 계산한 결측치 수를 reset_index 를 통해 데이터프레임으로 만들어 줍니다.
# df_null_count 변수에 결과를 담아서 head 로 미리보기를 합니다.

# %% [markdown]
# ## 컬럼명 변경하기

# %%
# df_null_count 변수에 담겨있는 컬럼의 이름을 "컬럼명", "결측치수"로 변경해 줍니다.

# %% [markdown]
# ## 정렬하기

# %%
# df_null_count 데이터프레임에 있는 결측치수 컬럼을 sort_values 를 통해 정렬해서
# 결측치가 많은 순으로 상위 10개만 출력합니다.

# %% [markdown]
# ## 특정 컬럼만 불러오기

# %%
# 지점명 컬럼을 불러옵니다.

# %%
# "컬럼명" 이라는 컬럼의 값만 가져와서 drop_columns 라는 변수에 담습니다.

# %%
# drop_columns 변수로 해당 컬럼 정보만 데이터프레임에서 가져옵니다.

# %% [markdown]
# ## 제거하기

# %% [markdown]
# ## 기초 통계값 보기

# %% [markdown]
# ### 기초 통계 수치

# %%
# 평균값

# %%
# 중앙값

# %%
# 최댓값

# %%
# 최솟값

# %%
# 개수

# %% [markdown]
# ### 기초통계값 요약하기 - describe
#
# describe 를 사용하면 데이터를 요약해 볼 수 있습니다.
# 기본적으로 수치형 데이터를 요약해서 보여줍니다.
# 데이터의 갯수, 평균, 표준편차, 최솟값,
# 1사분위수(25%), 2사분위수(50%), 3사분위수(75%), 최댓값을 볼 수 있습니다.

# %%
# 위도를 describe로 요약해 봅니다.

# %%
# 2개의 컬럼을 describe 로 요약합니다.

# %%
# describe로 문자열 데이터타입의 요약을 봅니다.

# %% [markdown]
# ### 중복제거한 값 보기
# * unique 로 중복을 제거한 값을 보고 nunique 로 갯수를 세어봅니다.

# %%
# "상권업종대분류명"

# %%
# "상권업종중분류명"

# %%
# "상권업종소분류명"

# %%
# nunique 대신 len 을 사용할 수도 있습니다.

# %% [markdown]
# ### 그룹화된 요약값 보기 - value_counts
# * value_counts 를 사용하면 카테고리 형태의 데이터 갯수를 세어볼 수 있습니다.

# %%
# value_counts 를 사용하면 카테고리 형태의 데이터 갯수를 세어볼 수 있습니다.
# 시도코드를 세어봅니다.

# %%
# 시도명을 세어봅니다.

# %%
# normalize=True 옵션을 사용하면 비율을 구할 수 있습니다.

# %%
# Pandas 에는 plot기능을 내장하고 있습니다.
# 위에서 분석한 시도명 수를 막대그래프로 표현해 봅니다.

# %%
# 판다스의 plot.pie()를 사용해서 파이그래프를 그려봅니다.

# %%
# "상권업종대분류명"으로 갯수를 세어봅니다.

# %%
# "상권업종중분류명"으로 갯수를 세어봅니다.

# %%
# normalize=True 를 사용해 비율을 구해봅니다.

# %%
# 판다스의 plot.bar()를 사용해서 막대그래프를 그려봅니다.

# %%
# 판다스의 plot.pie()를 사용해서 파이그래프를 그려봅니다.

# %%
# "상권업종소분류명" 에 대한 그룹화 된 값을 카운트 합니다.

# %%
# "상권업종소분류명"으로 갯수를 세어봅니다.
# 판다스의 plot.bar()를 사용해서 막대그래프를 그려봅니다.

# %% [markdown]
# ## 데이터 색인하기
# * 특정 데이터만 모아서 따로 봅니다.

# %%
# "상권업종중분류명"이 "약국/한약방"인 데이터만 가져와서
# df_medical 이라는 변수에 담아봅니다.
# 그리고 head()를 통해 미리보기를 합니다.

# %%
# "상권업종대분류명" 에서 "의료"만 가져옵니다.
# df.loc를 사용하면 행,열을 함께 가져올 수 있습니다.
# 이 기능을 통해 "상권업종중분류명" 만 가져옵니다.
# 그리고 가져온 결과를 value_counts 를 통해 중분류의 갯수를 세어봅니다.
# shop_type

# %%
# 위와 똑같은 기능을 수행하는 코드입니다. 아래와 같이 한 줄에 표현할 수도 있습니다.
# df.loc[df["상권업종대분류명"] == "의료", "상권업종중분류명"].value_counts()

# %%
# 유사의료업만 따로 모아봅니다.

# %%
# 상호명을 그룹화해서 갯수를 세어봅니다.
# value_counts 를 사용해서 상위 10개를 출력합니다.

# %%
# 유사의료업만 df_medi 변수에 담겨져 있습니다.
# df_medi 변수에서 상호명으로 갯수를 세어봅니다.
# 가장 많은 상호 상위 10개를 출력해 봅니다.

# %% [markdown]
# ### 여러 조건으로 색인하기

# %%
# "상권업종소분류명"이 "약국" 인 것과
# "시도명" 이 "서울특별시"인 데이터만 가져옵니다.
# df_seoul_drug

# %% [markdown]
# ### 구별로 보기

# %%
# 위에서 색인한 데이터로 "시군구명"으로 그룹화 해서 갯수를 세어봅니다.
# 구별로 약국이 몇개가 있는지 확인해 봅니다.

# %%
# normalize=True 를 통해 비율을 구해봅니다.

# %%
# 위에서 구한 결과를 판다스의 plot.bar()를 활용해 막대그래프로 그립니다.

# %%
# "상권업종소분류명"이 "종합병원" 인 것과
# "시도명" 이 "서울특별시"인 데이터만 가져옵니다.
# df_seoul_hospital

# %%
# "시군구명" 으로 그룹화 해서 구별로 종합병원의 수를 세어봅니다.

# %% [markdown]
# ### 텍스트 데이터 색인하기

# %%
# str.contains 를 사용해서 "상호명"에 "대학병원"이 들어가는 것을 가져와서 head()로 미리보기 합니다.

# %%
# str.startswith 를 사용해 "서울"로 시작하는 도로명주소를 가져와서 head()로 미리보기 합니다.

# %%
# str.endswith를 사용해서 "상호명"이 "병원"으로 끝나는 데이터를 가져와서 head()로 미리보기 합니다.

# %% [markdown]
# ### 특정 지역만 보기

# %%
# 서울에 있는 데이터의 위도와 경도를 봅니다.
# 결과를 df_seoul 이라는 데이터프레임에 저장합니다.
# 새로운 변수에 데이터프레임을 저장시 copy()를 사용합니다.
# df_seoul

# %%
# seaborn 의 countplot 을 사용해서 위에서 만든 df_seoul 데이터프레임의
# 시군구명을 시각화 합니다.
plt.figure(figsize=(9, 6))

# %%
# Pandas 의 plot.scatter 를 통해 경도와 위도를 표시해 봅니다.

# %%
# seaborn의 scatterplot 을 통해 구별 경도와 위도를 표시해 봅니다.
plt.figure(figsize=(16, 12))

# %%
# seaborn의 scatterplot 을 통해 "상권업종중분류명" 경도와 위도를 표시해 봅니다.
plt.figure(figsize=(16, 12))

# %%
# seaborn의 scatterplot 을 통해 전국 데이터(df)로 구별 경도와 위도를 표시해 봅니다.
plt.figure(figsize=(16, 12))

# %% [markdown]
# ## Folium 으로 지도 활용하기
# * 다음의 프롬프트 창을 열어 conda 명령어로 설치합니다.
# <img src="https://t1.daumcdn.net/cfile/tistory/99576B4A5B751DC902">
#
# 검은색 프롬프트 창에 아래 명령어를 통해 folium 을 설치합니다.
#
#
# `conda install -c conda-forge folium`
#
# ### Folium 사용예제
# http://nbviewer.jupyter.org/github/python-visualization/folium/tree/main/examples/

# %%
# 아나콘다에서 folium 을 사용하기 위해서는 별도의 설치가 필요
# https://anaconda.org/conda-forge/folium
# conda install -c conda-forge folium
# 지도 시각화를 위한 라이브러리

# %%
# geo_df 에 df_seoul_hospital 을 copy() 로 복사해서 할당합니다.

# %%
# 지도의 중심을 지정하기 위해 위도와 경도의 평균을 구합니다.

# %% [markdown]
# ## 좀 더 분석해 보기
# * 상권업종중분류명, 상권업종소분류명 중에 관심 있는 분류명을 색인 후에 시도별, 시군구별 분석을 해보세요.
# * 예시)
#     * 언어치료는 시군구별로 어디에 많이 위치할까?
#     * 의료시설은 서울과 강남에 집중되어 있을까?
#     * 강남에는 피부과, 성형외과가 다른 지역에 비해 많을까?
